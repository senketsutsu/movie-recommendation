# %% [markdown]
# # MovieLense

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd

# %%
def get_data(ds_name = 'movielens/100k-ratings'):
  def genre_id_to_text(genre_ids):
    return [genres[id] for id in genre_ids]

  ds=  tfds.load(ds_name, split='all')
  df = tfds.as_dataframe(ds)

  for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].apply(
            lambda x: x.decode('utf-8') if isinstance(x, bytes) else x
        )

  genres = ['Action' ,'Adventure' ,'Animation',
        'Children' ,'Comedy' ,'Crime' ,'Documentary' ,'Drama' ,'Fantasy',
        'Film-Noir' ,'Horror' ,'IMAX' ,'Musical' ,'Mystery' ,'Romance' ,'Sci-Fi',
        'Thriller' ,'War' ,'Western', 'unknown']
  df['genres_id'] = df['movie_genres']
  df['movie_genres'] = df['movie_genres'].apply(genre_id_to_text)

  return df

# %%
data = get_data()
# Out:
# 2024-11-17 15:18:34.820690: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
data.head()
# Out:
#    bucketized_user_age        movie_genres movie_id  \
# 0                 45.0             [Drama]      357
# 1                 25.0   [Comedy, Romance]      709
# 2                 18.0            [Comedy]      412
# 3                 50.0      [Crime, Drama]       56
# 4                 50.0  [Horror, Thriller]      895
#
#                               movie_title  raw_user_age  timestamp  \
# 0  One Flew Over the Cuckoo's Nest (1975)          46.0  879024327
# 1                Strictly Ballroom (1992)          32.0  875654590
# 2             Very Brady Sequel, A (1996)          24.0  882075110
# 3                     Pulp Fiction (1994)          50.0  883326919
# 4                         Scream 2 (1997)          55.0  891409199
#
#    user_gender user_id  user_occupation_label user_occupation_text  \
# 0         True     138                      4               doctor
# 1         True      92                      5        entertainment
# 2         True     301                     17              student
# 3         True      60                      4           healthcare
# 4         True     197                     18           technician
#
#    user_rating user_zip_code genres_id
# 0          4.0         53211       [7]
# 1          2.0         80525   [4, 14]
# 2          4.0         55439       [4]
# 3          4.0         06472    [5, 7]
# 4          3.0         75094  [10, 16]

# %%
df = pd.DataFrame(data, columns=['movie_id','user_id','user_rating'])
negative_ratings = df[ df['user_rating'] < 4 ].index 

df.drop(negative_ratings, inplace = True)

# %%
df = df.drop(columns=['user_rating'])

# %%
from sklearn.model_selection import train_test_split

# %%
config = {
    #embedding computation
    'cleora_n_iter': 5,
    'cleora_dim': 1024,
    
    #dataset preparation
    'train_test_split': 0.2,
    
    'batch_size': 256,
    'test_batch_size': 1000,
    'epochs': [10],
    'alpha': [1e-4],
}

# %%
train, test = train_test_split(df, test_size=config['train_test_split'])

# %%
train.shape, test.shape
# Out:
# ((44300, 2), (11075, 2))

# %%
len(train.groupby('user_id'))
# Out:
# 942

# %%
grouped_train = train.groupby('user_id')
for n, (name, group) in enumerate(grouped_train):
    if name=='1':
        continue
    print(group)
    break
# Out:
#       movie_id user_id
# 83324      664      10
# 97779      435      10
# 58473      617      10
# 51550      484      10
# 62751      519      10
# ...        ...     ...
# 14375      192      10
# 32654      371      10
# 51593      651      10
# 92579      133      10
# 606        182      10
#
# [140 rows x 2 columns]

# %%
ml_cleora_input_clique_filename = "../movielens/cleora_input_clique.txt"
ml_cleora_input_star_filename = "../movielens/cleora_input_star.txt"
ml_lp_train_filename = "../movielens/lp_train.txt"
ml_lp_test_filename = "../movielens/lp_test.txt"
output_dir = '../output'

# %%
with open(ml_cleora_input_clique_filename, "w") as f_cleora_clique, open(
    ml_cleora_input_star_filename, "w"
) as f_cleora_star, open(ml_lp_train_filename, "w") as f_train:
    grouped_train = train.groupby("user_id")
    for n, (name, group) in enumerate(grouped_train):
        group_list = group["movie_id"].tolist()
        group_elems = list(map(str, group_list))
        f_cleora_clique.write("{} {}\n".format(name, " ".join(group_elems)))
        f_cleora_star.write("{}\t{}\n".format(n, name))
        for elem in group_elems:
            f_train.write("{}\t{}\n".format(name, elem))
            f_cleora_star.write("{}\t{}\n".format(n, elem))

# %%
with open(ml_lp_test_filename, "w") as f_test:
    grouped_test = test.groupby('user_id')
    for name, group in grouped_test:
        group_list = group['movie_id'].tolist()
        group_elems = list(map(str, group_list))
        for elem in group_elems:
            f_test.write("{}\t{}\n".format(name, elem))

# %%
CLEORA_BINARY = '../src/cleora-v1.2.3-x86_64-unknown-linux-gnu'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.utils import shuffle
from tqdm import tqdm
import pandas as pd
from collections import Counter
import random
import os

# %%
import subprocess


def columns2output_filename(output_dir, columns):
    columns_split = columns.split()
    if len(columns_split) == 1 and 'reflexive' in columns:
        column_name = columns.split('::')[-1]
        return os.path.join(output_dir, f'emb__{column_name}__{column_name}.out')

    column_names = [i.split('::')[-1] for i in columns_split]
    return os.path.join(output_dir, 'emb__' + '__'.join(column_names) + '.out')


def train_cleora(dim, n_iter, columns, input_filename, output_dir):
    command = [CLEORA_BINARY,
                '--columns', columns,
                '--dimension', str(dim), 
                '-n', str(n_iter), 
                '--input', input_filename, 
                '-o', output_dir]
    subprocess.run(command, check=True)
    return columns2output_filename(output_dir, columns)

# %%
# %%time
cleora_output_star_filename = train_cleora(config['cleora_dim'], config['cleora_n_iter'], "transient::cluster_id StarNode", ml_cleora_input_star_filename, output_dir)
# Out:
# [2024-11-17T14:18:38Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 1024,
#     max_number_of_iteration: 5,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "../movielens/cleora_input_star.txt",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "../output",
#     ),
#     output_format: TextFile,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "cluster_id",
#             transient: true,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#         Column {
#             name: "StarNode",
#             transient: false,
#             complex: false,
#             reflexive: false,
#             ignored: false,
#         },
#     ],
# }
# [2024-11-17T14:18:38Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "cluster_id",
#         col_b_id: 1,
#         col_b_name: "StarNode",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-11-17T14:18:38Z INFO  cleora::pipeline] Number of lines processed: 10000
# [2024-11-17T14:18:38Z INFO  cleora::pipeline] Number of lines processed: 20000
# [2024-11-17T14:18:38Z INFO  cleora::pipeline] Number of lines processed: 30000
# [2024-11-17T14:18:38Z INFO  cleora::pipeline] Number of lines processed: 40000
# [2024-11-17T14:18:38Z INFO  cleora::sparse_matrix] Number of entities: 2382
# [2024-11-17T14:18:38Z INFO  cleora::sparse_matrix] Number of edges: 45242
# [2024-11-17T14:18:38Z INFO  cleora::sparse_matrix] Number of entries: 90388
# [2024-11-17T14:18:38Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 2 MB
# [2024-11-17T14:18:38Z INFO  cleora] Finished Sparse Matrices calculation in 0 sec
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Start initialization. Dims: 1024, entities: 2382.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Done initializing. Dims: 1024, entities: 2382.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Start propagating. Number of iterations: 5.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Done iter: 0. Dims: 1024, entities: 2382, num data points: 90388.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Done iter: 1. Dims: 1024, entities: 2382, num data points: 90388.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Done iter: 2. Dims: 1024, entities: 2382, num data points: 90388.
# [2024-11-17T14:18:38Z INFO  cleora::embedding] Done iter: 3. Dims: 1024, entities: 2382, num data points: 90388.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 4. Dims: 1024, entities: 2382, num data points: 90388.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done propagating.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Start saving embeddings.
# CPU times: user 4.9 ms, sys: 4.12 ms, total: 9.02 ms
# Wall time: 564 ms
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done saving embeddings.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-11-17T14:18:39Z INFO  cleora] Finished in 0 sec

# %%
# %%time
cleora_output_clique_filename = train_cleora(config['cleora_dim'], config['cleora_n_iter'], "complex::reflexive::CliqueNode", ml_cleora_input_clique_filename, output_dir)
# Out:
# CPU times: user 8.13 ms, sys: 1.02 ms, total: 9.15 ms
# Wall time: 20 ms
# [2024-11-17T14:18:39Z INFO  cleora] Reading args...
# [src/main.rs:222] &config = Configuration {
#     produce_entity_occurrence_count: true,
#     embeddings_dimension: 1024,
#     max_number_of_iteration: 5,
#     seed: None,
#     prepend_field: false,
#     log_every_n: 10000,
#     in_memory_embedding_calculation: true,
#     input: [
#         "../movielens/cleora_input_clique.txt",
#     ],
#     file_type: Tsv,
#     output_dir: Some(
#         "../output",
#     ),
#     output_format: TextFile,
#     relation_name: "emb",
#     columns: [
#         Column {
#             name: "CliqueNode",
#             transient: false,
#             complex: true,
#             reflexive: true,
#             ignored: false,
#         },
#     ],
# }
# [2024-11-17T14:18:39Z INFO  cleora] Starting calculation...
# [src/pipeline.rs:25] &sparse_matrices = [
#     SparseMatrix {
#         col_a_id: 0,
#         col_a_name: "CliqueNode",
#         col_b_id: 1,
#         col_b_name: "CliqueNode",
#         edge_count: 0,
#         hash_2_id: {},
#         id_2_hash: [],
#         row_sum: [],
#         pair_index: {},
#         entries: [],
#     },
# ]
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [1	197 268 246 221 183 57 50 169 77 202 75 194 182 204 241 45 20 168 32 28 170 209 192 203 253 47 107 195 14 191 162 66 193 81 184 129 172 173 56 133 86 7 108 18 124 196 257 15 16 256 109 269 207 137 59 161 212 239 248 12 152 178 146 160 242 68 13 43 214 249 113 72 84 51 52 151 185 210 111 174 134 76 132 88 175 157 89 64 1 224 3 23 154 46 95 223 150 234 190 177 230 93 251 25 163 119 48 199 222 128 216 229 235 198 165 176 79 267 171 22 6 265 42 127 65 227 91 96 87 60 80 258 208 238 82 61 187
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [10	664 435 617 484 519 156 116 179 289 698 69 157 132 611 495 176 230 197 710 603 274 170 321 656 510 59 475 602 199 185 137 195 499 712 707 604 286 606 701 478 699 134 706 56 164 33 509 486 497 155 504 513 470 493 525 502 463 16 521 50 696 153 48 178 505 276 205 40 168 474 708 488 700 160 588 4 340 333 9 479 22 527 32 82 93 615 135 482 161 654 124 694 498 367 496 357 283 610 709 221 582 180 200 285 589 275 194 334 432 711 162 483 531 418 174 467 11 447 385 302 530 218 629 480 98 234 705 238 85 1 223 186 23 245 518 192 371 651 133 182
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [100	879 898 751 344 328 294 691 690 750 900 752 313 302 272 315 347 316 269 1235
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [101	288 237 284 546 147 181 866 924 255 742 117 50 24
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [102	183 174 202 89 258 95 101 186 228 319 175 208 195 50 204 447 612
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [103	24 255 294 117 126 181 487 127 56 50 144
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [104	750 270 345 289 313 269 283 285 302 15 100 316 276 50 272 1012 181 475 290 751 257 628
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [105	270 288 268 286 327 269 313
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [106	28 313 77 59 660 684 778 923 191 107 1242 1 69 194 211 162 22 64 25 275 566 210 285 14 703 8 582 97 216 526 12 699 584
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [107	902 268 312 269 305
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [108	281 137 1 275 319 10 50 515 124 7 718 100 14
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [109	204 373 866 1135 735 739 164 174 403 411 294 77 423 121 809 568 566 117 520 159 79 98 223 89 176 588 91 31 147 252 385 229 88 388 173 257 11 228 1 67 1012 82 144 56 1014 191 295 234 451 508 237 202 70 96 95 1157 12 1222 181 72 15 22 222 69 233 665 845 218 1060 318 151 71 636 179 172 157 1016 25 365 195 380 265 53 17 258
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [11	544 9 203 56 750 731 125 425 707 713 737 423 268 22 291 524 749 393 690 356 258 111 402 549 196 286 237 239 135 51 740 357 318 332 15 47 729 433 241 434 428 603 736 277 745 752 86 107 312 79 28 8 427 659 229 317 301 652 208 692 100 699 230 527 173 663 350 194 83
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [110	402 307 739 333 11 41 233 682 272 82 326 939 12 69 423 315 651 88 258 161 451 28 54 94 692 33 569 96 313 566
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [111	313 311 328 302 333 242 340 286 269 301 315 304 258 354
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [112	888 315 286 306 322 310 272 303 312 346 316 307 754 690 750 937 333 689 751 245 887 289 300 328 313 1106 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [113	257 975 1251 327 255 326 127 508 595 258 325 979 323 328 100 50 303 273 874 268 126 246 1252 286
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [114	175 269 483 172 646 1104 496 156 357 183 179 482 176 100 195 197 135 98 522 659 474
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [115	82 192 431 443 628 654 357 92 558 240 273 79 696 174 1073 181 187 23 980 9 100 127 176 117 8 32 234 33 1008 466 1067 762 479 302 462 124 508 56 48 137 511 89 4 172 228 317 642 952
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [116	346 313 479 1134 390 203 259 193 655 310 661 292 268 187 750 258 596 730 250 191 900 1039 199 221 806 511 289 519 515 11 484 285 1142 271 181 344 56 127
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [117	179 117 151 751 1 222 195 173 237 282 132 265 33 268 772 174 628 109 249 1012 176 886 421 25 271 307 150 172 1016 156 742 789 168 15 423 98 56 405 313 597 678 214 144
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [118	288 474 547 475 175 185 558 800 919 156 22 184 210 551 134 1079 324 174 603 180 172 200 7 55 79 132 559 960 317 436 201 528 176 413 672 654 675 23 513 223 655 511 164 56 100 32 98 853 421 171 218
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [119	28 257 89 727 259 628 472 298 1137 924 277 385 11 591 64 451 597 458 455 137 83 829 109 1086 125 86 459 132 1160 486 7 1166 31 546 181 917 237 287 271 392 1260 144 537 506 301 449 188 511 50 718 286 328 235 568 210 121 199 1202 475 1197 716 1052 1261 25 9 685 562 182 275 405 209 268 87 316 826 124 310 96 193 154 313 274 174 282 742 1153 689 658 354 982 813 322 300 172 655 24 288 194 56 22 245 710 340 879 845 196 54
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [12	159 735 88 98 276 196 174 170 392 215 97 96 82 168 228 133 318 69 591 157 195 238 172 480 328 191 204 754 684 132 471 143 4 127 161 753 71 216 50 381 300 28 282
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [120	1 258 742 127 405 9 125 15 924 286 282 515 744
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [121	294 57 644 14 124 100 83 25 742 237 192 313 479 9 428 156 127 12 1266 427 137 1 717 135 631 515 937 357 257 509 98 172 315 736 86 318
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [122	1045 378 469 403 387 28 83 135 956 423 699 582 464 727 86 737 724 70 509 510 212 661 215 239 127 175 736 187 190 191 511 193 1044 519 269
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [123	98 100 23 22 485 14 504 135 127 462 187 182 276 192 165 511 185 847 657 319 275 9 432 479 483 285
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [124	195 11 98 550 168 96 144 616 154 7 226
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [125	144 82 568 478 1060 80 520 94 69 1 73 8 176 204 222 289 134 210 751 172 498 258 496 511 434 190 22 275 79 710 659 181 790 163 83 294 732 168 195 585 300 90 143 427 367 158 485 173 88 95 401 28 430 756 513 479 64 493 209 67 290 205 239 455 66 270 174 999 451 393 116
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [126	316 266 262 243 288 302 328 1175 344 878 681 315 313 311 258 751 353 300 881 337 340 884
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [127	50 748 901 228 288 380 343 449 450 230 229 300 258 294 62 227 222 271
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [128	83 684 69 190 143 88 462 422 458 181 159 265 216 1141 451 505 319 465 133 380 191 210 136 790 26 186 65 15 732 64 275 490 50 28 79 633 715 483 317 949 117 98 955 423 736 739 942 393 603 14 692 1 182 274 173 609 588 433 1039 591 140 197 478 82 168 196 506 276 507 238 180 508 283 427 482 838 405 378 568 487 209 161 651 763 602 471 300 48 686 99 223 418 71 425
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [129	302 906 286 1176 242 272 269
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [13	121 501 62 661 237 602 675 292 183 550 647 739 472 449 97 662 886 851 430 202 109 71 272 199 467 865 651 215 850 797 360 612 847 135 270 863 524 58 400 186 477 810 720 315 832 909 762 32 98 204 175 152 347 511 652 482 789 694 656 262 61 224 517 504 64 509 362 604 732 429 492 522 228 473 187 686 172 770 178 646 305 494 285 116 733 153 313 709 174 601 89 691 523 815 227 49 435 474 432 766 233 302 28 268 588 14 484 265 768 624 404 606 791 279 518 303 100 794 310 170 316 570 806 111 737 655 613 161 317 276 427 95 132 530 498 775 761 239 483 549 684 234 211 88 212 188 621 50 615 353 514 414 811 502 124 342 497 150 692 868 462 663 887 280 48 915 754 855 585 180 519 12 22 87 23 60 8 137 751 705 4 197 748 433 516 263 747 506 96 856 33 154 444 799 867 805 520 346 657 42 168 493 736 402 443 837 864 193 874 820 826
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [130	993 538 347 268 17 269 134 255 550 555 239 252 282 272 751 298 477 281 39 1028 249 111 508 183 682 748 118 946 1279 234 261 42 63 756 658 240 346 195 322 642 374 28 148 1208 895 291 625 5 215 105 3 96 763 975 316 49 12 820 501 222 379 93 343 752 66 366 123 444 597 765 330 496 1276 385 426 404 270 233 1046 94 452 56 128 236 271 288 672 329 246 427 294 808 185 393 794 121 332 95 196 286 11 188 934 50 326 405 258 7 742 216 816 894 267 235 174 321 1016 589 1019 546 890 82 305 469 1058 38 71 65 465 357 472 313 90 33 929 77 443 276 89 228 876 67 27 802 257 746 159 974 367 132 554 669 289 1039 176 1013 315 200 1217 800 143 150 684 62 449 1280 564 1136 355 1278 328 161 1 418 237 54 2 204 144 779 410 1220 64 203 98 293 219 226 729 44 419 229 147 79 184 412 333 22 358 532 578
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [131	14 276 845 285 297 19 1 124 744 1281 100 536 313 287 269 251 242 9 286 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [132	523 521 12 484 100 154 127 664 251 285
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [133	306 316 258 271 315 269 308
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [134	294 323 328 751 258 539 678 313 316 879 326 748
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [135	475 325 321 173 258 603 581 77 504 470 939 185 12 642 744 55 653 327 23
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [136	525 204 744 298 269 137 283 318 258 847 127 56 303 286 19 475 116 117 647 15 515 747 9 276 100 223 1142
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [137	172 249 546 117 15 261 121 181 680 237 748 183 405 118 144 1028 174 266 55 327 210 79 687 257 222 300 195 685 472 597 96
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [138	137 26 187 435 357 514 518 222 614 484 56 209 742 1 496 147 182 194 185 517 133 602 483 285 45 523 493 497 12 211 662 13 509 121 98 519 117 151 238
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [139	1176 127 508 458 307 676 288 303 297 268 286 296 1233 246 744
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [14	473 654 191 242 507 302 588 100 23 492 240 283 172 524 15 175 382 603 509 9 428 204 210 195 19 285 42 663 427 32 477 174 519 181 792 151 211 498 275 709 530 222 269 116 922 716 523 455 13 12 430 474 173 96 525 50 168 408 213 628
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [140	304 321 289 268 303 880 302 286 319
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [141	742 323 282 591 250 120 930 1047 258 619 597 410 117 974 222 984 322 106 252 328 237 313 825 815 985 244 535 300 678 546 15 7 125 50 121 926 1028 255 676 274 284 286 147 1023 294 281 472 866 181 298 118 409
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [142	169 7 425 28 408 346 333 42 91 189 514 895 124 134 82 181 350
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [143	328 313 272 347 307 315 288 326 271
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [144	170 176 197 1065 116 514 56 405 478 533 285 242 66 181 258 785 32 303 191 183 531 709 22 248 1142 64 48 196 212 655 855 297 1286 423 24 962 508 294 286 357 729 1101 778 845 198 304 153 751 318 1012 500 528 942 1138 273 72 19 747 126 880 124 59 15 1039 193 223 173 963 8 461 172 87 234 20 480 847 100 194 215 96 699 713 216 69 174 316 956 251 293 55 180 282 411 65 135 1 190 632 1226 647 1147 651 9 474 527 98 471 588 742 117 257 435 523 137 12 14 313 33 326 195 50 1197 127 144
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [145	246 54 299 182 650 11 176 56 64 510 635 185 294 354 23 436 200 117 544 356 278 342 348 242 195 552 652 713 164 816 1245 685 88 159 825 684 631 310 97 271 431 393 234 202 1001 42 302 96 470 471 879 515 315 949 230 327 98 181 268 235 313 237 410 270 591 1046 750 352 1288 1012 228 203 174 265 66 569 572 1273 301 329 752 150 789 742 448 282 284 12 156 240 219 7 316 925 674 328 363 100 257 135 281 597 172 250 1073 79 1208 31 273 761 222 227 688 293 869 549 13 22 939 39 258 183 209 134 343 566 1025 173
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [146	345 346 269 272 258 1022 319 302 340 311 313 262 245 1294
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [147	269 305 898 345 750 690 340 286 904 302 304 319 292 301
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [148	194 495 175 588 70 969 209 228 56 596 222 71 474 1012 135 227 357 172 89 132 507 408 50 509 238 114 169 181 151 501 7 173 133 164 1 214 69 432 993 174
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [149	340 269 313 303 305 268 346 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [15	257 15 310 220 181 300 255 864 308 936 471 275 937 50 690 458 274 137 685 125 927 620 283 866 306
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [150	276 235 291 147 246 151 288 123 319 50 127 410 221 273 13 324 14 129 628 1 475 181 268
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [151	4 505 88 15 435 610 1050 1070 1113 197 25 89 482 499 121 9 58 193 837 724 512 216 522 429 321 66 487 171 473 208 971 190 162 301 164 135 381 478 185 286 154 663 836 523 317 945 729 443 792 466 44 114 204 659 382 486 411 509 654 65 28 371 707 224 196 485 919 202 172 70 628 160 709 813 134 186 582 1286 133 234 163 845 414 10 497 1298 1197 660 125 111 428 835 209 516 735 87 657 525 463 97 258 277 228 408 198 972 1 629 483 423 211 143 782 432 1299 662 504 378 265 189 380 507 52 549 50 174 7 181 430 425 614 494 170 474 420 490 652 609 464 287 14 602 222 480 73 705 661 136 168 274 939 56 736 178 51 488 491 1101 98 638 1264 953 64 86 151 275 300 93 605 655 498 223 169 69 210 529 173 506 124 966 461 137 132 528 387 969 699 770 213
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [152	283 410 66 790 393 487 740 215 1041 161 313 866 763 1300 121 204 71 685 739 49 241 162 699 8 191 775 1301 153 780 280 278 234 724 294 781 785 504 125 716 371 549 944 117 255 660 51 364 272 568 720 155 1136 794 167 632 88 692 132 1053 402 1035 286 483 966 15 157 22 97 133 220
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [153	357 79 56 568 182 265 64 258
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [154	484 474 187 89 175 488 211 61 152 515 414 238 640 185 191 135 357 286 182 172 200 523 479 527 641 482 174
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [155	286
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [156	317 646 137 48 651 641 58 211 157 661 180 357 187 9 100 197 178
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [157	50 235 269 508 1051 1016 293 100 298 340 137 313 117 289 1 273 268 244 1258 515 1302 147 276 410 150 274 286
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [158	177 271 1098 8 7 430 985 4 116 38 168 187 285 1067 194 284 770 516 431 290 518 144 286 403 79 745 744 137 302 277 85 127 576 742 483 228 176 580 659 210 39 293 414 686 825 175 89 502 118 190 511 367 648 24 455 202 694 1 22 129 651 172 250 11 55 124 111 154 174 50 525 82 593 62 96 568 530 173 435 636 275 209 56 1047 204 562 810 241
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [159	1190 243 930 1014 1152 405 1095 1013 829 126 127 322 451 546 323 756 25 258 1049 471 273 7 96 293 871 294 591 1221 1012 918 310 225 118 333 220 276 1028 117 125 678 249 685 1132 259 24 245 595
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [16	657 134 96 191 385 482 56 661 202 947 732 447 95 71 197 160 240 208 273 583 603 87 156 151 684 502 12 135 152 127 939 92 234 1 164 69 194 172 692 55 410 39 942 427 443 79 227 302 496 99 168 183 467 199 480 642 70 8 143 531 591 357 606 693 602 31 28 318 9 654 423 200 7 216 98 945 178 404 448 51 946 629 174 195 294 161 182 237 209 228 100 504 22 705 180 76
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [160	129 497 1 763 248 157 514 174 213 671 55 410 11 13 50 137 293 544 169 240 175 1016 693 150 276 474 1134 160 288 430 282 117 218 209 185 461 202 59 285 201 234 922 151 32 488 192 475 955 211 250 123 531 458 195 127 1142 273 135 603 508 455 100 770 79 408 124 4 302 1197 56 61
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [161	186 272 100 202 315 98 69 316 14
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [162	28 1011 1047 1012 222 1019 181 628 117 508 11 1 544 943 597 174
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [163	98 357 258 318 316 97 272
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [164	299 823 370 118 281 689 125 322 100 258 329 515 252 9 690 282 866 121 328 751 300 293 619 313 117 405 984 222 1025 748 472 245 248 930 597 307
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [165	174 181 216 91 651 318 176 15 127 326 325 222 419 169 432 372 270 202 258
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [166	313 343 347 328 323 258 751 894 984 322
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [167	222 735 318 237 659 137 1125 530 521 435 1306 1126 478 641 133 603 1200 238 241 655 606 8 513 204 381 216 698 486 96 83 1147 99 673
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [168	1197 845 1016 121 294 25 282 291 117 1051 258 300 1 280 744 257 866 409 225 819 295 125 313 151 1012 596 274 742 15 222
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [169	172 684 879 603 174 258 480 234 604 606 300 301 199 538 50 331 133 443 211 213 181
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [17	137 126 100 7 919 276 1 150 151
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [170	326 749 300 333 304 984 292 322 678
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [171	268 269 887 302 270 303 315 262 258 310 292 327 346
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [172	582 580 642 124 428 183
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [173	324 329 995 327 323 299 332 300 262 874 690 331 242 319 245 322 292 258 301 303 326 268 305 334 879 289 880 328 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [174	14 724 655 215 953 937 276 147 69 471 248 155 949 846 823 582 160 451 196 1035 1074 65 107 347 117 111 739 1028 1041 237 696 845 15 708 56 402 764 126 716 100 1313 1262 1053 293 87 312 278 216 239 9 340 1312 125 781 332 49 162 433 50 315 280 143 124 12 269 1221 934 699 197 648 178 709 371 476 70 742 333 381 1086 246 221 202 1282 238 31 98 762 393 140
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [175	187 88 111 50 127 419 98 64 9 172 31 133 661 483 496 186 11 193 71 183
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [176	458 240 1097 328 321 270 273 268 285 305 93 150 50 236 347 874 875 151 7 117 262 1008 298 340 111 222 272 258 345 1012 13 246 293 750
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [177	203 182 186 469 294 187 12 508 156 1067 806 42 223 64 160 527 7 60 693 92 210 100 183 324 11 173 470 172 642 403 333 197 174 154 919 144 302 59 209 318 168 340 181 654 23 153 175 299 1218 50 87 56 198 176 89 179 307 276 433 195 135 98 475
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [178	51 568 173 174 926 124 696 293 223 209 427 241 478 685 199 55 168 155 809 316 216 82 1004 1016 500 183 58 125 202 484 111 196 234 98 269 16 187 96 71 193 845 70 250 181 100 274 1 578 549 258 331 531 28 219 246 153 99 591 87 95 651 684 226 178 588 318 454 233 655 66 410 131 232 12 433 89 423 435 77 7 79 993 31 97 143 1315 1119 62 275 511 491 1101 300 342 520 1012 8 1258 265 302 117 118 735 257 127 658 195 248 1035 204 326 367 472 354 781 495 255 679 385 15 222 238 230 1169 283 69 229 729 763 471 280 203 792 748 50 11 215 133 268 64 431 172 288 313 1197 194 866 597 144 123 210
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [179	301 315 272 313 316 914 258 340 333 905 305 302 288 682 354
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [18	663 95 59 529 65 463 805 56 214 357 189 48 12 960 79 286 432 162 143 485 58 116 15 709 753 514 45 856 187 549 489 285 212 208 154 13 61 387 318 427 9 169 8 516 955 166 14 510 659 963 430 83 714 86 513 971 965 52 213 526 60 631 190 530 175 186 479 276 524 275 211 99 136 223 70 287 126 493 221 504 209 512 242 22 582 216 515 528 6 435 132 64 283 792 613 612 416 958 179 660 134 131 735 404 50 71 238 224 633 523 381 23 492 588 480 137 962 414 174 113 497 180 142 474 210 639 647 487 527 191 182
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [180	631 56 733 694 462 83 423 156 69 747 961 1131 213 421 173 431 222 372 98 380 191 684 729 111 121 318 469 658 40 53 68
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [181	282 220 289 591 974 222 288 25 7 280 237 274 121 405 270 682
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [182	178 111 423 596 50 191 123 471 181 15 126 172 69
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [183	720 227 483 177 274 273 230 55 216 649 228 212
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [184	272 527 1020 582 212 792 708 221 451 208 945 509 478 321 65 262 487 596 640 237 1010 181 93 14 182 1086 127 511 70 71 676 692 813 506 191 517 357 89 498 313 654 492 381 52 51 473 521 1 172 134 497 124 508 715 1136 604 694 216 116 855 1137 504 523 9 647 707 98 276 66 657 836 1101 514 100 531 606 86 183 1396 95 286 393 196 1121 207 1398 274 950 50 423 25 275 137 215 602 724 283 644 213 58 780 371 318 428 462 165 387 378 187 340 44 20 480 382
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [185	1020 514 86 23 302 515 111 275 286 178 480 318 279 114 181 50 528 9 216 237 447 269 25 690 321 197 196 47 285 199 287 116
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [186	477 925 159 147 257 203 546 100 44 38 550 689 596 330 684 55 98 566 887 148 829 31 1016 79 1277 77 306 385 332 226 988 225 1042 300 591 291 470 1253 540 117 322 939
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [187	462 214 213 433 707 116 23 660 427 168 70 423 196 83 651 792 135 209 86 275 300 191 1065 65 736 210 28 747 428 197 735 173 186 216 694 69
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [188	13 22 468 392 77 97 930 121 234 204 216 553 173 356 484 498 11 218 88 443 127 764 419 455 470 673 199 174 148 76 162 568 100 717 300 265 357 143 153 628 7 180 98 692 632 483 318 177 176 164 79 69 288 211 566 591 474 5 651
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [189	1372 97 191 847 225 204 136 150 99 501 433 661 510 134 50 952 13 14 198 520 1099 199 197 1020 499 170 480 505 174 1402 100 607 157 517 246 28 1005 275 647 1060 474 473 486 274 172 527 234 1404 8 500 89 652 127 24 176 603 498 180 135 4 656 1401 196 1098 294 523 568 423 487 10 194 632 166 863 485 317 1117 582 526 511 318 513 657 694 496 483 185 484 638 248 238 253 512 44 175 1403 151 143 179 751 216 659 83 459 56 462 639
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [19	211 8 153 435 887 319 202
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [190	300 148 354 751 7 628 269 544 15 326 591 222 333 302 288 245 310 313 273 100 237 117 471 272
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [191	313 300 86 345 750 315 272 302 340 331 301
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [192	301 284 287 9 813 258 50 7 100 340 1405 257 1160 1061 515 1137 302 25 127 289
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [193	182 407 435 347 310 307 443 905 580 280 739 177 313 627 276 187 218 1168 673 1 742 393 755 23 941 553 199 127 153 1078 210 693 117 301 194 69 845 508 237 79 159 366 300
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [194	518 124 648 165 507 199 22 792 13 483 186 317 173 144 218 529 502 661 521 496 523 211 9 44 735 223 238 466 193 168 647 294 64 23 527 663 52 185 432 69 157 588 530 28 194 467 693 204 510 15 580 98 100 192 515 503 56 191 265 657 837 357 188 659 511 520 427 526 136 161 12 474
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [195	500 651 591 135 181 273 234 1418 1193 582 213 328 276 127 242 1014 615 143 823 751 258 1084 304 134 298 507 47 1315 421 1089 496 14
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [196	692 381 382 238 111 108 8 306 845 286 153 285 25 655 663 1118 428 1007 393 411
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [197	89 511 161 684 576 879 22 570 510 195 566 181 176 665 187 300 265 449 289 183 50 230 362 96 177 313 228 554 245 258 272 233 294 127 651 232 750 172 226 568 328 526 1228 210 79
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [198	526 509 475 200 217 50 1 96 154 186 64 654 191 629 187 69 746 1245 193 151 318 81 942 531 210 403 173 651 7 1169 258 183 56 197 382 132 429 1142 198 174 23 172 979 179 182 447 216 168 357 188 660 11 427 214 480 511
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [199	7 258 242 473 475 269 313 221 276 508 116 285
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [2	283 310 292 269 316 275 311 299 313 301 284 272 100 1 282 14 293 304 297 237 277 111 13 285 306 276 279 242 255 303
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [20	274 82 742 87 15 633 934 678 22 588 174 181 118 568 323 210
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [200	222 419 423 478 230 527 380 8 118 147 225 188 515 528 509 720 82 195 294 228 123 549 443 378 431 451 771 258 191 88 802 357 208 1217 172 28 578 673 373 71 568 1 313 276 202 570 204 183 840 91 196 392 176 929 22 7 812 465 559 174 69 89 552 63 483 679 280 420 215 393 288 79 94 96 596 205 282 325 72 496 117 582 665 125 173 179 33 135 132 141 365 169 385 318 1091 597 470 685 234 229 576 25 739 432 177 402 586 99 95 473 429 227 50 462 1228 9 892 241 742 62 58 674 140 560 768 831 760 15 193 866 29 68 951 11 304 148
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [201	1208 855 172 196 176 582 318 325 234 26 479 346 227 144 468 655 1070 129 640 697 1169 556 1174 55 190 715 213 1137 237 480 223 588 458 46 98 1128 651 607 1100 157 956 334 192 772 197 93 1398 423 324 1268 185 469 587 853 216 991 596 408 313 271 42 160 288 447 203 4 47 79 204 331 285 137 150 506 260 268 50 188 1170 508 792 435 670 127 201 1428 76 482 708 1194 1135 33 1131 183 198 767 242 59 340 86 218 11 156 275 134 56 656 191 642 96 200 65 405 182 693
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [202	484 604 195 516 96
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [203	150 50 117 326 283 628 815 477 93 276 222 181 24 151 250
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [204	9 482 216 301 170 242 12 292 1296 262 1194 340 269 316 1022 45 191 297 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [205	333 748 289 315 326
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [206	288 269 272 313 258 310 895 333 748 346 1127 315 302
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [207	161 871 127 515 211 1197 79 468 1046 273 746 316 269 59 520 302 197 153 1283 208 216 428 393 87 205 64 435 187 712 25 318 313 483 98 742 133 28 527 23 186 735 14 282 357 423 42 566 196 4 509 242 529 568 69 258 655 526 660 174 1147 134 508 143 1242 609
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [208	523 208 663 197 310 430 97 662 435 194 428 216 202 514 88 402 393 524 371 211
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [209	293 16 1137 285 1086 181 50 766 813 251 408 321
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [21	218 200 301 637 844 17 854 127 436 9 671 875 100 244 53 326 558 635 201 234 15 185 448 98 324 447 656 273 330 993 219 298 184 452 325 7
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [210	234 174 205 514 23 181 651 403 172 735 655 301 132 290 423 447 435 1012 302 153 167 180 465 483 135 134 357 402 732 79 28 631 692 65 98 173 197 202 168 160 25 1 97 58 96 274 657 50 501 204 186 161 404 4 211 195 419 208 969 88 276 94 187 517 708 200 114 255 222 1118 523 152 420 185 216 327 73 443 15 56 484
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [211	457 705 117 127 423 520 257 286 205
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [212	631 423 515 197 246 286 527 427 382 268 317 86 528
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [213	176 212 515 154 143 831 156 273 274 284 582 11 13 463 42 735 56 100 12 234 199 127 121 655 568 455 79 591 170 195 603 55 194 192 514 218 135 458 475 180 64 214 288 257 627 200 106 483 172 117 841 173 238 175 546 924 48 509 213 182 98 118 132 511 318 181 684 521 193 24 50 692 597 478 447 187 197 432 357 144 628 157
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [214	253 114 121 318 1401 92 324 479 1039 64 171 608 174 191 196 175 188 856 42 708 522 209 482 496 166 134 327 285 216 213 127 603 169 55 1017 12 187 156 93 516 461 462 1129 56 509 568 475 527 180 650 512 182 185 11 483 508 478 427 89 151 100 179 173 238 79 45 23 117 705 896 652 1073 137 313 221 39 408 32
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [215	227 28 226 216 194 89 99 517 56 483 474 127 271 196 181 443 132 210 449 157 523 197 186 54 168 421 185 179 313 64 144 496 195 202 234 228 172 191 434 134 176 50 222 423 357 208 480 174
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [216	69 81 50 98 234 218 28 204 421 182 172 188 357 12 286 315 134 202 238 237 122 496 55 789 298 174 79 943 129 168 276 144 1067 11 216 184 721 3 4 9 7 22 200 150 1161 156 210 466 282 100 65 697 42 97 318 735 313 628 47 58 423 82 91
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [217	118 210 566 679 195 684 403 300 578 685 96 11 117 222 82 231 56 597 797 391 761 233 33 665 176 568
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [218	657 466 168 153 648 516 209 23 33 55 762 1073 269 603 659 183 273 98 176 42 47 203
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [219	215 269 936 855 382 179 4 664 879 132 433 906 546 631 303
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [22	50 222 568 187 792 511 692 399 118 385 204 238 526 127 451 176 250 144 17 393 80 403 510 181 161 358 128 228 4 216 651 258 208 68 153 168 290 79 209 523 109 89 430 184 502 117 515 195 227 230 732 174 154 712 194 431 186
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [220	306 303 682 298 288 305 300 301 268 289 294 286
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [221	246 1217 544 346 48 92 156 385 172 55 268 789 64 467 100 475 1073 117 210 684 1134 3 282 144 286 178 79 7 231 204 273 27 847 1059 181 250 272 186 695 17 1098 23 327 940 550 508 33 39 240 751 318 721 96 218 403 56 24 737 257 578 1017 943 215 732 1011 42 651 763 1012 12 298
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [222	71 276 228 693 365 50 127 172 328 215 588 56 1057 118 537 73 628 549 385 48 198 62 298 232 153 54 173 436 182 195 77 95 209 271 155 750 423 237 11 756 318 356 248 79 619 392 69 22 164 689 796 219 258 183 313 300 214 9 257 527 431 521 97 402 246 755 12 1226 185 28 685 1011 568 7 64 67 210 282 204 1042 475 449 135 100 393 742 1 591 161 31 176 433 746 82 72 223 174 380 732 1220 98 1438 1044 895 735 68 655 1284 66 222 125 739 710
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [223	820 155 682 69 993 257 546 969 309 278 298 332 470 1014 333 237 255 28 845 173 339 274 866 71 282 95
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [224	380 222 662 403 77 553 193 731 191 846 239 387 660 655 196 686 468 526 318 392 282 215 22 1039 470 582 300 178 51 402 157 280 727 15 570 294 69 162 423 720 326 28
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [225	1443 566 64 418 98 492 427 215 22 478 480 194 193 286 1203 482 510 606 604 237 603
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [226	174 7 176 527 56 405 180 28 286 9 14 12 509 89 242 179 25 813 191 258 480 270 109 408 224 150 713
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [227	1017 13 116 1143 93 285 19 15 7 25 124 319 411 295 274 287 276 129 137 221 475 14 126 293 50 1011
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [228	690 272 427 655 651 812 313
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [229	898 882 269 311 286 302 288 344
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [23	705 185 194 79 132 418 55 177 216 95 222 238 96 694 50 124 153 250 530 511 386 174 195 14 175 629 170 380 171 603 541 961 528 230 408 518 381 427 710 224 8 588 652 405 173 504 211 98 516 404 463 59 131 133 100 134 1 919 19 116 275 432 527 7 713 385 189 172 856
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [230	291 549 588 70 214 963 153 211 969 172 64 435 11 405 650 582 204 680 498 294 266 420 280 423 142 134 496 371 28 427 117 168 1 141 185 402 570 154 443 239 265 95 162 418 223 216 210 739 304 97 699 1192 161 419 100 82 8 22 143 951 484 451 378 98 51 515 234 196 485 186 633 432
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [231	252 15 289 924 846 748 405 181 50
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [232	419 50 52 523 435 14 91 708 302 357 276 638 493 425 1149 4 921 655 423 166 132 133 173 165 318 461 204 197 81 246 186 705 175 194 196 172 250 531 98 483 56 32 289 272 900 100 96 474 1 268
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [233	257 654 614 523 64 603 223 568 293 261 180 506 177 647 584 215 48 483 193 82 504 191 69 56 269 588 318 462 633 194 98 495 70 923 57 845 644 216 135 275 47 828 100 806 515 197 423 1194 187 509 418 482 528 192 375 205 95 498 14 208 133 660 357 97 127 249 143 527 174 435
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [234	1169 490 792 481 638 836 656 432 318 229 466 1121 106 430 558 770 745 463 842 98 414 507 602 197 641 970 675 224 234 404 634 510 423 124 705 23 367 921 464 285 166 170 615 513 484 20 673 31 1456 100 8 504 187 200 28 52 91 178 134 927 660 427 488 473 419 505 528 1221 519 50 4 428 1449 847 867 69 135 1397 613 499 99 494 663 1126 416 1445 923 964 525 661 127 64 1203 483 582 152 242 378 657 610 654 199 1452 495 502 313 611 429 165 136 206 474 523 480 45 515 191 506 22 1021 289 1186 607 479
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [235	923 192 197 1176 269 170 86 175 346 1451 237 100 96 474 230 523 193 652 463 655 87 971 520 194 79 705 522 179 494 318 435 303 211 319 524 195 213 480 70 648 496 344 692 684 69 1193 429 207 191 275 433 52 185 515 1149 792 7 970
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [236	199 133 692 750 549 79 427 132 69 15 591 483 328 520 237 729 286 1102 64 934 735 443 673 97 148 699 423 9 307 170 203 420 28 57 143 282 546 127 223 705 432 111 506 185 98 298 216 304 134 614 181 435 56
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [237	190 169 100 23 58 211 183 408 513 174 178 525 180 83 498 28 179 127 494 485 98 134 659 197 656 603 474 423 357 199 514 64 238 191 502
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [238	111 298 300 471 257 121 405 458
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [239	632 39 116 516 50 484 150 46 923 663 753 1056 340 174 474 96 172 512 1204 511 508 633 42 527 507 183 479 428 135 194 475 1099 855 675 124 421 954 1065 221 961 242 499 56 210 9 8 14 317 647 137 497 605 650 65 745 478 558 701 45 528 134 634 483 434 179 505 1070 433 171 463 530 491 513 187 836 504 89 736 185 529 162 238 493 1203 276 443 652 12 509 921 498 671 209 272 91
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [24	117 7 153 127 477 92 372 655 97 402 100 1007 742 662 9 79 508 41 25 56 173 223 729 237 300 421 475 11 180 357 64 582 324 318 518 12 69 276 176 216 8 178 238 427 258
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [240	340 242 307 288 313 898 245 286 301
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [241	887 292 288 880 307
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [242	331 361 1355 934 275 305 237 1137 283 268 740
#     ] is skipped.
# ...
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [908	694 56 496 185 657 127 963 528 427 204 484 478 133 525 423 558 98 479 631 483 183 223 144 79 709 648 515 318 28 50 591 701 100 96
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [909	509 116 286 261 326 292 166 165 14 300 170 880 224 382 339 275 707 86 1121
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [91	511 318 614 195 172 427 182 210 527 327 205 616 82 331 181 1192 529 343 322 333 64 176 612 98 507 127 515 657 662 601 234 423 484 135 479 689 603 429 50 480 289 328 750 183 300 357 651 28 187 483 22 134 495 192 338
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [910	237 1 405 414 12 222 127 845 300 313 357 23 684 117 56 100 183 174 742 50
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [911	428 168 93 625 194 134 482 173 399 154 480 423 163 204 478 709 474 228 435 21 197 1060 185 923 969 272 431 183 855 443 151 647 209 203 87 190 419 208 153 174 172 465 142 83 603 143 216 588 193 1039 655 638 89
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [912	610 154 602 479 15 152 132 173 97 318 357 28 443 14 64 427 143 423 523 501 496 168 655 498
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [913	92 216 83 789 655 64 57 185 144 127 750 741 963 475 99 302 228 58 131 527 234 173 478 98 657 22 169 79 56 204 4 50 289 168 203 95 89 7 12 176 265 174 317 11 461 9 191 613 427
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [914	1406 155 643 197 371 781 402
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [915	286 750 691 302 268 345 315 347
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [916	1070 475 236 265 971 484 483 183 7 14 52 53 28 210 512 241 234 170 157 198 1011 1113 943 83 86 168 286 17 428 60 4 221 89 246 1 727 194 959 58 527 697 244 111 581 382 190 461 238 9 92 1098 462 64 640 39 98 175 223 50 721 97 387 960 91 173 509 530 213 181 318 56 593 652 216 715 193 1073 134 135 557 150 172 176 48 531 474 511 735 421 203 919 154 250 42 806 1005 582 46 100 317 156 11 1101 767 1010 88 180 12 217 82 650
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [917	150 268 628 471 285 25 535 289 248 9 740 246 696 237 100 756
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [918	921 582 1266 213 971 1200 16 606 965 507 1639 923 631 83 498 170 28 709 137 275 1099 856 1101 381 659 143 64 704 962 660 1065 86 855 707 382 1137 1195 190 165 499 25 972
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [919	204 676 200 221 527 325 14 22 895 303 271 367 111 260 1277 1197 147 305 99 98 340 558 419 140 70 432 937 218 343 272 1101 174 1086 223 331 1278 1152 1012 418 1014 58 715 742 19 660 125 16 302 275 304 300 287 259 93 794 151 1137 332 64 293 191 95 508 9 813 129 382 201 100 423 285 144 82 25 282 277 57 582 15 297 283 255 270 327 217 307 313 258
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [92	531 421 51 11 12 651 692 521 274 9 209 619 403 223 747 591 408 222 528 181 121 715 1208 98 276 189 79 679 1142 258 96 993 385 13 47 198 69 382 433 673 518 823 129 214 174 466 64 144 1216 500 628 164 203 640 56 961 58 411 204 273 1 31 159 581 291 239 947 169 157 180 124 65 175 186 515 431 566 778 92 228 71 4 268 436 655 190 153 8 789 471 191 1194 708 855 193 183 265 195 134 171 955 660 238 707 208 135 1073 160 631 50 963 245 196 212 304 1018 582 89 125 176 215 663 463 475 737 1012 218 248
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [920	347 310 340 1612 333
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [921	419 1032 720 815 328 15 143 50 202 313 72 222 69 210 196 121 274 136 380 181 133 252 538 367 174 173 755 79 659 845 692 1028 1016 284 526 323 66
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [922	68 449 384 98 258 432 50 427 181 77 202 227 455 290 228 153 172 143 265 421 919 222 91 451 99 51 11 588 406 72 1 229 382 949 810 22 151 746 83 433 576 15 395 431 89 1110 174 71
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [923	325 237 1028 168 282 307 1012 3 1011 9 825 741 762 50 829 975 129 546 333 181 338 823 544 456 148 295 151 288 291 294 628 276 815 411 866 334 105 248 340 472 928 293 685 100 322 742 125 257 926 174 591 763 460
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [924	178 100 205 527 318 313 174 471 134 6 496 519 427 216 173 195 1478 12 433 523 632 196 82 129 1400 9 429 511 28 896 421 1 237 202 701 923 504 7 64 275 283 153 705 228
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [925	185 325 323 5 447 218 288 332
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [926	258 269 302 272 340 315
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [927	111 426 91 380 422 328 402 385 421 1035 1093 63 405 1089 210 71 288 8 568 155 28 230 411 449 204 11 168 222 1284 541 928 237 552 96 409 1016 763 403 404 300 393 374 471 67 1047 826 64 1415 756 228 367 15 121 118 138 255 72
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [928	268 878 135 173 269 8 127 48 487 172 496 165 358 246 9 1025 98 134 168 187 877 276 266 114 191 749 876
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [929	429 135 50 134 479 12 185 188 423 172 521 187 28 419 204 98 483 589 127 195 182 89
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [93	222 477 815 1 235 14 476 283 15 275
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [930	106 282 64 238 300 116 244 275 709 274 281 121 126 535 190 165 45
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [931	245 127 304 275 508 14 333 312 690 744 302 100 344 181 255 272 316 303 116 313 459 515 286 347 900 297 750 293 909 125 1152 298
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [932	89 516 380 530 1205 863 506 163 189 709 157 521 462 178 430 210 204 494 570 167 170 1065 511 208 153 647 165 136 517 197 428 414 229 478 513 228 566 203 805 134 603 1116 479 180 525 135 54 495 1397 133 179 502 435 174 632 196 1454 503 199 168 1449 285 676 1266 443 141 1 172 611 705 519 175 14 515 650 496 606 70 183 211 86 646 1149 1121 616 745 1558 615 510 169 205 209 524 529 493 498 357 194 613 612 434 639 405 523 1035 429 1204 480 432 1126 483 659 1411 1456 617 778 661 1050 614 675 507 657 56 488 520 47 504 9 119 486 427 7 527 212 154 491 475 811 1020 162 654 514 526 45 30 474 191 177 274 198 968 185
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [933	64 127 187 523 56 193 100 318 135 182 12 180 654 144 367 179 470 87 89 22 789 200 211 125 156 28 357 435 177 183 196 157 194 50 317 483 174 746 69
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [934	229 705 4 492 427 100 624 50 712 732 1203 174 196 514 254 855 650 286 144 89 663 965 168 210 197 811 403 226 428 963 135 181 94 82 97 2 96 384 432 303 163 755 502 161 794 605 297 132 461 584 664 152 414 237 495 507 481 131 195 13 420 1411 69 630 675 193 70 501 25 175 56 961 83 172 211 902 805 1449 449 190 674 223 462 506 302 550 510 257 617 661 554 134 660 703 208 67
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [935	864 286 15 148 476 121 117 281 471 313 284 282 742 815 125 237 300 274 846 1016 127 118 934 181 597 255
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [936	7 20 904 272 124 108 121 1368 845 1241 818 181 1 19 1011 251 250 325 236 547 1344 313 927 286 476 1370 919 93 24 285 127 346 1171 276 100 1008 268 253 475 1202 13 1097 275 324 237 340 358 249 813 25 864 248 825 137 14 1160 125 1323 6 756 1007 269 591 117 129 319 1129 1377 281 1163 287 741 289 50
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [937	224 515 126 303 293 847 275 93 300 285 297 9 236 304 116 283 50 408 124 14 295
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [938	273 1028 1061 358 252 288 866 370 1014 225 106 763 50 993 298 243 258 257 333 864 127 100 762 1012 126 458 313 222 508 121 596 476 343 111 928 291 220 118 181 25
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [939	258 1028 220 255 756 546 476 280 1051 127 689 742 1054 222 275 1023 597 841 1190 15 1277 717 9 237 118 121 283 405 298 326
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [94	1147 508 93 1011 746 92 97 421 192 61 806 206 650 510 1223 399 603 923 961 410 313 549 58 420 219 1135 173 132 652 448 625 8 436 127 367 246 185 447 1010 432 156 589 584 636 55 268 997 789 357 527 1044 1058 160 423 684 528 168 204 9 265 537 111 31 250 1048 53 209 824 1014 302 484 942 172 12 735 201 372 70 435 83 193 587 657 693 1 741 386 458 655 654 235 151 82 109 176 22 949 1218 433 181 525 135 7 644 56 715 469 180 506 346 1211 317 646 133 483 154 475 188 11 588 45 64 157 464 501 196 286 404 170 631 959 431 428 993 217 194 1012 273 470 642 100 1007 651 736 81 939 1110 134 616 402 356 347 50 509 692 1219 647 969 381 338 186 177 4 175 258 153 183 696 49 471 241 1153 234 143 91 727 465 737 425 98 1226 76 686 813 467 792 203 211 238 474 47 504
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [940	521 657 147 354 315 191 56 316 8 482 357 66 194 96 50 272 82 321 508 285 855 430 89 436 204 216 317 313 1167 209 269 258 238 516 259 427 628 95 302 420 294 173 651 692 170 678 7 12 655 709
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [941	993 181 257 1 298 294 300 475 7 124 1007 455 408 147 15
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [942	216 316 215 607 427 528 318 357 705 478 1050 172 347 511 71 259 435 498 945 878 272 750 97 31 484 174 265 210 1028 258 95 261 310 124 480 79 193 315 969 282 661 514 414 659 500 479 1221 496 234 300 304 197 520 662 131 50
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [943	42 526 470 195 24 2 403 27 367 431 1074 55 426 11 188 475 427 210 187 232 226 485 23 173 356 840 193 172 471 69 98 581 233 216 943 816 194 721 808 685 54 94 205 576 22 28 546 12 218 200 76 201 186 215 184 196 655 92 182 928 31 824 151 732 111 559 64 385 68 739 717 181 672 174 56 100 79 508 237
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [95	233 1116 198 170 88 139 210 399 385 286 550 28 7 568 650 539 660 1221 98 64 657 48 209 404 174 196 127 79 328 507 219 178 742 655 202 736 649 474 622 15 121 491 436 692 141 204 99 73 175 70 250 393 144 181 173 378 625 274 357 510 186 14 747 226 1206 94 627 420 77 651 1 143 473 216 423 68 389 83 1126 472 843 518 511 194 445 527 153 96 207 705 199 183 463 111 433 591 462 631 31 356 238 532 65 520 168 22 91 515 257 117 282 496
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [96	483 265 127 170 1232 1 91 156 200 8 195 176 144 87 514 673 484 519 89 423 182 216 56 198 474 153 318 190 174 96 234 7 1154 23 64 479 445 185 183 645 79 50
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [97	50 191 82 202 174 132 204 228 435 168 189 603 115 7 1 670 32 98 183 69 153 172 23 919 222 79 430 28 432 423 661 655 482 408 97 89 135 428 195 208
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [98	47 210 629 523 211 435 517 514 25
#     ] is skipped.
# [2024-11-17T14:18:39Z WARN  cleora::pipeline] Wrong number of columns (expected: 1, provided: 2). The line [99	1 410 402 172 313 748 232 210 240 204 595 203 4 363 100 780 237 403 628 763 258 173 22 196 64 182 328 329 315 11 147 433 50 273 79 1048 405 471 117 125 294 238 98 174 92 651 12 508 473 597 369 348 168 69 288 789 1132 7 544 290
#     ] is skipped.
# [2024-11-17T14:18:39Z INFO  cleora::sparse_matrix] Number of entities: 0
# [2024-11-17T14:18:39Z INFO  cleora::sparse_matrix] Number of edges: 0
# [2024-11-17T14:18:39Z INFO  cleora::sparse_matrix] Number of entries: 0
# [2024-11-17T14:18:39Z INFO  cleora::sparse_matrix] Total memory usage by the struct ~ 0 MB
# [2024-11-17T14:18:39Z INFO  cleora] Finished Sparse Matrices calculation in 0 sec
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Start initialization. Dims: 1024, entities: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done initializing. Dims: 1024, entities: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Start propagating. Number of iterations: 5.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 0. Dims: 1024, entities: 0, num data points: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 1. Dims: 1024, entities: 0, num data points: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 2. Dims: 1024, entities: 0, num data points: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 3. Dims: 1024, entities: 0, num data points: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done iter: 4. Dims: 1024, entities: 0, num data points: 0.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done propagating.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Start saving embeddings.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Done saving embeddings.
# [2024-11-17T14:18:39Z INFO  cleora::embedding] Finalizing embeddings calculations!
# [2024-11-17T14:18:39Z INFO  cleora] Finished in 0 sec

# %%
def read_embeddings(input_file):
    df_full = pd.read_csv(input_file, delimiter = " ", skiprows=[0], header=None, 
                     index_col=0)
    df_full = df_full.drop([1], axis=1)  
    return df_full

# %%
def read_train_test(embeddings):
    valid_idx = embeddings.index.to_numpy()
    train = np.loadtxt(ml_lp_train_filename, delimiter="\t", dtype=np.int32)
    test = np.loadtxt(ml_lp_test_filename, delimiter="\t", dtype=np.int32)
    
    #valid pairs of nodes
    train = train[np.isin(train[:,0], valid_idx) & np.isin(train[:,1], valid_idx)]
    test = test[np.isin(test[:,0], valid_idx) & np.isin(test[:,1], valid_idx)]
    
    #negatives for testset: top 100 most common nodes
    all_idx = train.flatten()
    ctr = Counter(all_idx)
    negatives = ctr.most_common(100)
    negatives = [ n[0] for n in negatives ]
    
    adjacency_dict = dict()
    for inp, out in np.vstack([test, train]):
        if inp not in adjacency_dict:
            adjacency_dict[inp] = set()
        adjacency_dict[inp].add(out)

    return train, test, negatives, adjacency_dict, valid_idx

# %%
batch_size = config['batch_size']
test_batch_size = config['test_batch_size']

# %%
for algo in [cleora_output_star_filename, cleora_output_clique_filename]:
    embeddings = read_embeddings(algo)
    train_1, test_1, negatives, adjacency_dict, valid_idx = read_train_test(embeddings)
    #for faster operation, draw only 1000 test examples
    test_ex = random.sample(list(test_1), 1000)
    
    #these are the 10.000 most common nodes selected as negatives for each valid testing node pair
    df_neg = embeddings.loc[negatives]
    neg_ids = set(df_neg.index)

    epoch = max(config['epochs'])
    for a in config['alpha']:
        #create a binary classifier outputting whether a node pair represents a valid edge (1) or not a valid edge (0)
        clf = SGDClassifier(random_state=0, loss='log_loss', alpha=a)
        for e in range(0, epoch):
            np.random.shuffle(train_1)
            
            for idx in tqdm(range(0,train_1.shape[0],batch_size)):
                #ones = real pairs of nodes
                #zeros = fake pairs of nodesF
                ones=train_1[idx:min(idx+batch_size,train_1.shape[0]),:]
                
                ones_emb_in = embeddings.loc[ones[:,0]].to_numpy()
                ones_emb_out = embeddings.loc[ones[:,1]].to_numpy()
                #Hadamard
                ones = np.multiply(ones_emb_in,ones_emb_out)
                
                id_train_0_in = np.random.choice(valid_idx, size=len(ones), replace=True)
                id_train_0_out = np.random.choice(valid_idx, size=len(ones), replace=True)
    
                zeros_emb_in = embeddings.loc[id_train_0_in].to_numpy()
                zeros_emb_out = embeddings.loc[id_train_0_out].to_numpy()
                #Hadamard
                zeros = np.multiply(zeros_emb_in, zeros_emb_out)
    
                x_train = np.vstack([ones, zeros])
                y_train = [1]*len(ones) + [0]*len(ones)

                clf.partial_fit(x_train, y_train, classes=[0,1])

            if e+1 in config['epochs']:
                mrr = 0.0
                hr = 0.0
                for n, ex in enumerate(test_ex):
                    l = ex[0]
                    r = ex[1]

                    emb_l = embeddings.loc[l].to_numpy().reshape([1, -1])
                    emb_r = np.vstack((df_neg.to_numpy(), embeddings.loc[r].to_numpy()))
        
                    full_ex = np.hstack([np.repeat(emb_l, len(emb_r), axis=0), emb_r])
                    hadamard = np.multiply(emb_l, emb_r)
                    preds = clf.predict_proba(hadamard)[:,1]
                    preds = np.array(preds)

                    #do not punish for high scores of items from trainset and others from testset
                    forbidden_ex = adjacency_dict[l]
                    df_mask = [0 if (elem in forbidden_ex) else 1 for elem in neg_ids]
                    #last elem is always valid
                    df_mask.append(1)
                    preds *= df_mask
            
                    ranking = (-preds).argsort()
                    rank = np.isin(ranking, 100).nonzero()[0][0]+1
                    mrr += 1/rank
                    hr += (rank <= 10)
                    
                    if (n+1)%100 == 0:
                        print('mrr ', mrr/(n+1), ' hr@10 ', hr/(n+1))

                print('algo: {} epochs: {} lr: {}, mrr: {}, hr@10: {}'.format(algo, str(e+1), a, mrr/len(test_ex), hr/len(test_ex)))
# Out:
# 100%|██████████| 174/174 [00:04<00:00, 35.06it/s]
# 100%|██████████| 174/174 [00:04<00:00, 36.21it/s]
# 100%|██████████| 174/174 [00:04<00:00, 38.45it/s]
# 100%|██████████| 174/174 [00:04<00:00, 37.81it/s]
# 100%|██████████| 174/174 [00:04<00:00, 35.50it/s]
# 100%|██████████| 174/174 [00:04<00:00, 35.90it/s]
# 100%|██████████| 174/174 [00:04<00:00, 35.75it/s]
# 100%|██████████| 174/174 [00:04<00:00, 34.94it/s]
# 100%|██████████| 174/174 [00:04<00:00, 35.19it/s]
# 100%|██████████| 174/174 [00:04<00:00, 35.82it/s]
# mrr  0.12701636835752506  hr@10  0.19
# mrr  0.1262138867292136  hr@10  0.18
# mrr  0.11318428150756174  hr@10  0.16333333333333333
# mrr  0.11941422410424049  hr@10  0.1775
# mrr  0.10413082097642093  hr@10  0.158
# mrr  0.10915006535860101  hr@10  0.16333333333333333
# mrr  0.10808217234436701  hr@10  0.16428571428571428
# mrr  0.1035582738313365  hr@10  0.15875
# mrr  0.10178279588794283  hr@10  0.15555555555555556
# mrr  0.10646457830168778  hr@10  0.162
# algo: ../output/emb__cluster_id__StarNode.out epochs: 10 lr: 0.0001, mrr: 0.10646457830168778, hr@10: 0.162
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 for algo in [cleora_output_star_filename, cleora_output_clique_filename]:
# ----> 2     embeddings = read_embeddings(algo)
#       3     train_1, test_1, negatives, adjacency_dict, valid_idx = read_train_test(embeddings)
#       4     #for faster operation, draw only 1000 test examples
#
# Cell In[46], line 2, in read_embeddings(input_file)
#       1 def read_embeddings(input_file):
# ----> 2     df_full = pd.read_csv(input_file, delimiter = " ", skiprows=[0], header=None,
#       3                      index_col=0)
#       4     df_full = df_full.drop([1], axis=1)
#       5     return df_full
#
# File ~/.local/share/virtualenvs/movie-recommendation-KK-5LRNj/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/share/virtualenvs/movie-recommendation-KK-5LRNj/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/share/virtualenvs/movie-recommendation-KK-5LRNj/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/share/virtualenvs/movie-recommendation-KK-5LRNj/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.local/share/virtualenvs/movie-recommendation-KK-5LRNj/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
test.shape
# Out:
# (11075, 2)
